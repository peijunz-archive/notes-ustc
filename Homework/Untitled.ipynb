# %%
# %pylab
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib

# %%
def tab2(x,y,fun):
    return array([[fun(i,j) for j in range(y)] for i in range(x)])

# %%
s=tab2(20,20,lambda x,y:(sin(x/20)+sin(y/20)))

# %%
matshow(s)

# %%
f=lambda x,y:sp.var((x*x-y*y))

# %%
f(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-c0c95413393f> in <module>()
# ----> 1 f(1,2)
#
# <ipython-input-24-11ac194d1a4b> in <lambda>(x, y)
# ----> 1 f=lambda x,y:sp.var((x*x-y*y))
#
# /usr/lib/python3.5/site-packages/sympy/core/symbol.py in var(names, **args)
#     589
#     590     try:
# --> 591         syms = symbols(names, **args)
#     592
#     593         if syms is not None:
#
# /usr/lib/python3.5/site-packages/sympy/core/symbol.py in symbols(names, **args)
#     537         return tuple(result)
#     538     else:
# --> 539         for name in names:
#     540             result.append(symbols(name, **args))
#     541
#
# TypeError: 'int' object is not iterable

# %%
sp.Rational
